# %%
import os
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# c:\users\multicampus\appdata\local\programs\python\python36\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# 1데이터 불러오기

# %%
df_movies = pd.read_csv('movies.csv')
df_ratings=pd.read_csv('ratings.csv')
# 불필요한 컬럼은 지우기
df_movies = df_movies.drop(['genres'], axis=1)
df_ratings=df_ratings.drop(['timestamp'], axis=1)

# %%
movies_filename = 'movies.csv'
ratings_filename = 'ratings.csv'

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating
# 0       1       31     2.5
# 1       1     1029     3.0
# 2       1     1061     3.0
# 3       1     1129     2.0
# 4       1     1172     4.0

# %%
df_movies.head()
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)

# %% [markdown]
# 2 reshaping the data 데이터 가공하기

# %%
from scipy.sparse import csr_matrix
# pivot ratings into movie features -- movie-user 로 이루어진 매트릭스 만들기
movie_user_matrix = df_ratings.pivot(
    index='movieId',
    columns='userId',
    values='rating'
).fillna(0)

# create mapper from movie title to index -- 무비 타이틀을 인덱스로 바꾸기?
movie_to_idx = {
    movie: i for i, movie in 
    enumerate(list(df_movies.set_index('movieId').loc[movie_user_matrix.index].title))
}

# convert dataframe of movie features to scipy sparse matrix -- 매트릭스를 sparse 매트릭스로 바꾸기
movie_user_mat_sparse = csr_matrix(movie_user_matrix.values)

# %%
# create mapper from movie title to index -- 무비 타이틀을 인덱스로 바꾸기?
movie_to_idx = {
    movie: i for i, movie in 
    enumerate(list(df_movies.set_index('movieId').loc[movie_user_matrix.index].title))
}
movie_to_idx
# Out:
# {'Toy Story (1995)': 0,
#  'Jumanji (1995)': 1,
#  'Grumpier Old Men (1995)': 2,
#  'Waiting to Exhale (1995)': 3,
#  'Father of the Bride Part II (1995)': 4,
#  'Heat (1995)': 5,
#  'Sabrina (1995)': 6,
#  'Tom and Huck (1995)': 7,
#  'Sudden Death (1995)': 8,
#  'GoldenEye (1995)': 9,
#  'American President, The (1995)': 10,
#  'Dracula: Dead and Loving It (1995)': 11,
#  'Balto (1995)': 12,
#  'Nixon (1995)': 13,
#  'Cutthroat Island (1995)': 14,
#  'Casino (1995)': 15,
#  'Sense and Sensibility (1995)': 16,
#  'Four Rooms (1995)': 17,
#  'Ace Ventura: When Nature Calls (1995)': 18,
#  'Money Train (1995)': 19,
#  'Get Shorty (1995)': 20,
#  'Copycat (1995)': 21,
#  'Assassins (1995)': 22,
#  'Powder (1995)': 23,
#  'Leaving Las Vegas (1995)': 24,
#  'Othello (1995)': 25,
#  'Now and Then (1995)': 26,
#  'Persuasion (1995)': 27,
#  'City of Lost Children, The (Cité des enfants perdus, La) (1995)': 28,
#  'Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)': 29,
#  'Dangerous Minds (1995)': 30,
#  'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)': 31,
#  'Babe (1995)': 32,
#  'Carrington (1995)': 33,
#  'Dead Man Walking (1995)': 34,
#  'Across the Sea of Time (1995)': 35,
#  'It Takes Two (1995)': 36,
#  'Clueless (1995)': 37,
#  'Cry, the Beloved Country (1995)': 38,
#  'Richard III (1995)': 39,
#  'Dead Presidents (1995)': 40,
#  'Restoration (1995)': 41,
#  'Mortal Kombat (1995)': 42,
#  'To Die For (1995)': 43,
#  'How to Make an American Quilt (1995)': 44,
#  'Seven (a.k.a. Se7en) (1995)': 45,
#  'Pocahontas (1995)': 46,
#  'When Night Is Falling (1995)': 47,
#  'Usual Suspects, The (1995)': 48,
#  'Mighty Aphrodite (1995)': 49,
#  'Lamerica (1994)': 50,
#  'Big Green, The (1995)': 51,
#  'Georgia (1995)': 52,
#  'Home for the Holidays (1995)': 53,
#  'Postman, The (Postino, Il) (1994)': 54,
#  'Confessional, The (Confessionnal, Le) (1995)': 55,
#  'Indian in the Cupboard, The (1995)': 56,
#  'Eye for an Eye (1996)': 57,
#  "Mr. Holland's Opus (1995)": 58,
#  "Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996)": 59,
#  'Two if by Sea (1996)': 60,
#  'Bio-Dome (1996)': 61,
#  'Lawnmower Man 2: Beyond Cyberspace (1996)': 62,
#  'French Twist (Gazon maudit) (1995)': 63,
#  'Friday (1995)': 64,
#  'From Dusk Till Dawn (1996)': 65,
#  'Fair Game (1995)': 66,
#  'Kicking and Screaming (1995)': 67,
#  'Misérables, Les (1995)': 68,
#  'Bed of Roses (1996)': 69,
#  'Screamers (1995)': 70,
#  'Nico Icon (1995)': 71,
#  'Crossing Guard, The (1995)': 72,
#  'Juror, The (1996)': 73,
#  'White Balloon, The (Badkonake sefid) (1995)': 74,
#  "Things to Do in Denver When You're Dead (1995)": 75,
#  "Antonia's Line (Antonia) (1995)": 76,
#  'Once Upon a Time... When We Were Colored (1995)': 77,
#  'Last Summer in the Hamptons (1995)': 78,
#  'Angels and Insects (1995)': 79,
#  'White Squall (1996)': 80,
#  'Dunston Checks In (1996)': 81,
#  'Black Sheep (1996)': 82,
#  'Nick of Time (1995)': 83,
#  'Mary Reilly (1996)': 84,
#  'Vampire in Brooklyn (1995)': 85,
#  'Beautiful Girls (1996)': 86,
#  'Broken Arrow (1996)': 87,
#  'In the Bleak Midwinter (1995)': 88,
#  'Hate (Haine, La) (1995)': 89,
#  'Shopping (1994)': 90,
#  'Heidi Fleiss: Hollywood Madam (1995)': 91,
#  'City Hall (1996)': 92,
#  'Bottle Rocket (1996)': 93,
#  'Mr. Wrong (1996)': 94,
#  'Unforgettable (1996)': 95,
#  'Happy Gilmore (1996)': 96,
#  'Bridges of Madison County, The (1995)': 97,
#  'Muppet Treasure Island (1996)': 98,
#  'Catwalk (1996)': 99,
#  'Braveheart (1995)': 100,
#  'Taxi Driver (1976)': 101,
#  'Rumble in the Bronx (Hont faan kui) (1995)': 102,
#  'Before and After (1996)': 103,
#  "Margaret's Museum (1995)": 104,
#  'Anne Frank Remembered (1995)': 105,
#  "Young Poisoner's Handbook, The (1995)": 106,
#  'If Lucy Fell (1996)': 107,
#  'Steal Big, Steal Little (1995)': 108,
#  'Boys of St. Vincent, The (1992)': 109,
#  'Boomerang (1992)': 110,
#  'Chungking Express (Chung Hing sam lam) (1994)': 111,
#  "Star Maker, The (Uomo delle stelle, L') (1995)": 112,
#  'Flirting With Disaster (1996)': 113,
#  'NeverEnding Story III, The (1994)': 114,
#  'Pie in the Sky (1996)': 115,
#  'Angela (1995)': 116,
#  'Frankie Starlight (1995)': 117,
#  'Jade (1995)': 118,
#  'Down Periscope (1996)': 119,
#  'Man of the Year (1995)': 120,
#  'Up Close and Personal (1996)': 121,
#  'Birdcage, The (1996)': 122,
#  'Brothers McMullen, The (1995)': 123,
#  'Bad Boys (1995)': 124,
#  'Amazing Panda Adventure, The (1995)': 125,
#  'Basketball Diaries, The (1995)': 126,
#  'Awfully Big Adventure, An (1995)': 127,
#  'Amateur (1994)': 128,
#  'Apollo 13 (1995)': 129,
#  'Rob Roy (1995)': 130,
#  'Addiction, The (1995)': 131,
#  'Batman Forever (1995)': 132,
#  'Beauty of the Day (Belle de jour) (1967)': 133,
#  'Beyond Rangoon (1995)': 134,
#  'Blue in the Face (1995)': 135,
#  'Canadian Bacon (1995)': 136,
#  'Casper (1995)': 137,
#  'Clockers (1995)': 138,
#  'Congo (1995)': 139,
#  'Crimson Tide (1995)': 140,
#  'Crumb (1994)': 141,
#  'Desperado (1995)': 142,
#  'Devil in a Blue Dress (1995)': 143,
#  'Die Hard: With a Vengeance (1995)': 144,
#  'Doom Generation, The (1995)': 145,
#  'Feast of July (1995)': 146,
#  'First Knight (1995)': 147,
#  'Free Willy 2: The Adventure Home (1995)': 148,
#  'Hackers (1995)': 149,
#  'Jeffrey (1995)': 150,
#  'Johnny Mnemonic (1995)': 151,
#  'Judge Dredd (1995)': 152,
#  'Jury Duty (1995)': 153,
#  'Kids (1995)': 154,
#  'Living in Oblivion (1995)': 155,
#  'Lord of Illusions (1995)': 156,
#  'Love & Human Remains (1993)': 157,
#  'Mad Love (1995)': 158,
#  'Mallrats (1995)': 159,
#  'Mighty Morphin Power Rangers: The Movie (1995)': 160,
#  'Mute Witness (1994)': 161,
#  'Nadja (1994)': 162,
#  'Net, The (1995)': 163,
#  'Nine Months (1995)': 164,
#  'Party Girl (1995)': 165,
#  'Prophecy, The (1995)': 166,
#  'Reckless (1995)': 167,
#  'Safe (1995)': 168,
#  'Scarlet Letter, The (1995)': 169,
#  'Showgirls (1995)': 170,
#  'Smoke (1995)': 171,
#  'Something to Talk About (1995)': 172,
#  'Species (1995)': 173,
#  'Strange Days (1995)': 174,
#  'Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)': 175,
#  'Tie That Binds, The (1995)': 176,
#  'Three Wishes (1995)': 177,
#  'Total Eclipse (1995)': 178,
#  'To Wong Foo, Thanks for Everything! Julie Newmar (1995)': 179,
#  'Under Siege 2: Dark Territory (1995)': 180,
#  'Unstrung Heroes (1995)': 181,
#  'Unzipped (1995)': 182,
#  'Walk in the Clouds, A (1995)': 183,
#  'Waterworld (1995)': 184,
#  "White Man's Burden (1995)": 185,
#  'Browning Version, The (1994)': 186,
#  'Burnt by the Sun (Utomlyonnye solntsem) (1994)': 187,
#  'Before the Rain (Pred dozhdot) (1994)': 188,
#  'Before Sunrise (1995)': 189,
#  'Billy Madison (1995)': 190,
#  'Babysitter, The (1995)': 191,
#  'Boys on the Side (1995)': 192,
#  'Cure, The (1995)': 193,
#  'Castle Freak (1995)': 194,
#  'Circle of Friends (1995)': 195,
#  'Clerks (1994)': 196,
#  'Don Juan DeMarco (1995)': 197,
#  'Disclosure (1994)': 198,
#  'Drop Zone (1994)': 199,
#  'Destiny Turns on the Radio (1995)': 200,
#  'Death and the Maiden (1994)': 201,
#  'Dolores Claiborne (1995)': 202,
#  'Dumb & Dumber (Dumb and Dumber) (1994)': 203,
#  'Eat Drink Man Woman (Yin shi nan nu) (1994)': 204,
#  'Exotica (1994)': 205,
#  'Exit to Eden (1994)': 206,
#  'Ed Wood (1994)': 207,
#  'French Kiss (1995)': 208,
#  'Forget Paris (1995)': 209,
#  'Far From Home: The Adventures of Yellow Dog (1995)': 210,
#  'Goofy Movie, A (1995)': 211,
#  'Hideaway (1995)': 212,
#  'Fluke (1995)': 213,
#  'Farinelli: il castrato (1994)': 214,
#  'Gordy (1995)': 215,
#  'Gumby: The Movie (1995)': 216,
#  'The Glass Shield (1994)': 217,
#  'Hoop Dreams (1994)': 218,
#  'Heavenly Creatures (1994)': 219,
#  'Houseguest (1994)': 220,
#  'Immortal Beloved (1994)': 221,
#  'Heavyweights (Heavy Weights) (1995)': 222,
#  'Hunted, The (1995)': 223,
#  'I.Q. (1994)': 224,
#  'Interview with the Vampire: The Vampire Chronicles (1994)': 225,
#  'Jefferson in Paris (1995)': 226,
#  'Jerky Boys, The (1995)': 227,
#  'Junior (1994)': 228,
#  'Just Cause (1995)': 229,
#  "Kid in King Arthur's Court, A (1995)": 230,
#  'Kiss of Death (1995)': 231,
#  'Star Wars: Episode IV - A New Hope (1977)': 232,
#  'Little Women (1994)': 233,
#  'Little Princess, A (1995)': 234,
#  'Ladybird Ladybird (1994)': 235,
#  "Enfer, L' (1994)": 236,
#  'Like Water for Chocolate (Como agua para chocolate) (1992)': 237,
#  'Legends of the Fall (1994)': 238,
#  'Major Payne (1995)': 239,
#  'Little Odessa (1994)': 240,
#  'My Crazy Life (Mi vida loca) (1993)': 241,
#  'Love Affair (1994)': 242,
#  'Losing Isaiah (1995)': 243,
#  'Madness of King George, The (1994)': 244,
#  "Mary Shelley's Frankenstein (Frankenstein) (1994)": 245,
#  'Man of the House (1995)': 246,
#  'Mixed Nuts (1994)': 247,
#  'Milk Money (1994)': 248,
#  'Miracle on 34th Street (1994)': 249,
#  'Miami Rhapsody (1995)': 250,
#  'My Family (1995)': 251,
#  'Murder in the First (1995)': 252,
#  "Nobody's Fool (1994)": 253,
#  'Nell (1994)': 254,
#  'New Jersey Drive (1995)': 255,
#  'Beyond Bedlam (1993)': 256,
#  'Nina Takes a Lover (1994)': 257,
#  'Natural Born Killers (1994)': 258,
#  'Only You (1994)': 259,
#  'Once Were Warriors (1994)': 260,
#  'Poison Ivy II (1996)': 261,
#  'Outbreak (1995)': 262,
#  'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)': 263,
#  'Perez Family, The (1995)': 264,
#  "Pyromaniac's Love Story, A (1995)": 265,
#  'Pulp Fiction (1994)': 266,
#  'Priest (1994)': 267,
#  'Quiz Show (1994)': 268,
#  'Picture Bride (Bijo photo) (1994)': 269,
#  'Queen Margot (Reine Margot, La) (1994)': 270,
#  'Quick and the Dead, The (1995)': 271,
#  'Roommates (1995)': 272,
#  'Ready to Wear (Pret-A-Porter) (1994)': 273,
#  'Three Colors: Red (Trois couleurs: Rouge) (1994)': 274,
#  'Three Colors: Blue (Trois couleurs: Bleu) (1993)': 275,
#  'Three Colors: White (Trzy kolory: Bialy) (1994)': 276,
#  'Red Firecracker, Green Firecracker (Pao Da Shuang Deng) (1994)': 277,
#  'Stuart Saves His Family (1995)': 278,
#  'Swan Princess, The (1994)': 279,
#  'Secret of Roan Inish, The (1994)': 280,
#  'Specialist, The (1994)': 281,
#  'Stargate (1994)': 282,
#  'Santa Clause, The (1994)': 283,
#  'Shawshank Redemption, The (1994)': 284,
#  'Shallow Grave (1994)': 285,
#  'Suture (1993)': 286,
#  'Strawberry and Chocolate (Fresa y chocolate) (1993)': 287,
#  'Swimming with Sharks (1995)': 288,
#  'Sum of Us, The (1994)': 289,
#  "National Lampoon's Senior Trip (1995)": 290,
#  'To Live (Huozhe) (1994)': 291,
#  'Tank Girl (1995)': 292,
#  'Tales from the Crypt Presents: Demon Knight (1995)': 293,
#  'Star Trek: Generations (1994)': 294,
#  'Tales from the Hood (1995)': 295,
#  'Tom & Viv (1994)': 296,
#  'Village of the Damned (1995)': 297,
#  'Tommy Boy (1995)': 298,
#  'Vanya on 42nd Street (1994)': 299,
#  'Underneath (1995)': 300,
#  'Walking Dead, The (1995)': 301,
#  "What's Eating Gilbert Grape (1993)": 302,
#  'Virtuosity (1995)': 303,
#  'While You Were Sleeping (1995)': 304,
#  'War, The (1994)': 305,
#  'Double Happiness (1994)': 306,
#  "Muriel's Wedding (1994)": 307,
#  'Baby-Sitters Club, The (1995)': 308,
#  'Ace Ventura: Pet Detective (1994)': 309,
#  'Adventures of Priscilla, Queen of the Desert, The (1994)': 310,
#  'Backbeat (1993)': 311,
#  'Bitter Moon (1992)': 312,
#  'Bullets Over Broadway (1994)': 313,
#  'Clear and Present Danger (1994)': 314,
#  'Client, The (1994)': 315,
#  'Corrina, Corrina (1994)': 316,
#  'Crooklyn (1994)': 317,
#  'Crow, The (1994)': 318,
#  'Cobb (1994)': 319,
#  'Flintstones, The (1994)': 320,
#  'Forrest Gump (1994)': 321,
#  'Four Weddings and a Funeral (1994)': 322,
#  'Higher Learning (1995)': 323,
#  'I Love Trouble (1994)': 324,
#  'It Could Happen to You (1994)': 325,
#  'Jungle Book, The (1994)': 326,
#  'Wonderful, Horrible Life of Leni Riefenstahl, The (Macht der Bilder: Leni Riefenstahl, Die) (1993)': 327,
#  'Lion King, The (1994)': 328,
#  'Little Buddha (1993)': 329,
#  "Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale, A) (1994)": 330,
#  'Mask, The (1994)': 331,
#  'Maverick (1994)': 332,
#  'Mrs. Parker and the Vicious Circle (1994)': 333,
#  'Naked Gun 33 1/3: The Final Insult (1994)': 334,
#  'Paper, The (1994)': 335,
#  'Reality Bites (1994)': 336,
#  'Red Rock West (1992)': 337,
#  'Richie Rich (1994)': 338,
#  'Safe Passage (1994)': 339,
#  'River Wild, The (1994)': 340,
#  'Speed (1994)': 341,
#  'Speechless (1994)': 342,
#  'Timecop (1994)': 343,
#  'True Lies (1994)': 344,
#  'When a Man Loves a Woman (1994)': 345,
#  'Wolf (1994)': 346,
#  'Wyatt Earp (1994)': 347,
#  'Bad Company (1995)': 348,
#  'Low Down Dirty Shame, A (1994)': 349,
#  'Boys Life (1995)': 350,
#  'Colonel Chabert, Le (1994)': 351,
#  'Faster Pussycat! Kill! Kill! (1965)': 352,
#  "Jason's Lyric (1994)": 353,
#  'Secret Adventures of Tom Thumb, The (1993)': 354,
#  'Street Fighter (1994)': 355,
#  'Mirage (1995)': 356,
#  'Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension) (1994)': 357,
#  'In the Mouth of Madness (1995)': 358,
#  '8 Seconds (1994)': 359,
#  'Above the Rim (1994)': 360,
#  'Addams Family Values (1993)': 361,
#  'Age of Innocence, The (1993)': 362,
#  'Airheads (1994)': 363,
#  'Air Up There, The (1994)': 364,
#  'Another Stakeout (1993)': 365,
#  'Bad Girls (1994)': 366,
#  'Barcelona (1994)': 367,
#  'Being Human (1993)': 368,
#  'Beverly Hillbillies, The (1993)': 369,
#  'Beverly Hills Cop III (1994)': 370,
#  'Black Beauty (1994)': 371,
#  'Blink (1994)': 372,
#  'Blown Away (1994)': 373,
#  'Blue Chips (1994)': 374,
#  'Blue Sky (1994)': 375,
#  'Body Snatchers (1993)': 376,
#  'Boxing Helena (1993)': 377,
#  'Bronx Tale, A (1993)': 378,
#  'Cabin Boy (1994)': 379,
#  "Carlito's Way (1993)": 380,
#  "City Slickers II: The Legend of Curly's Gold (1994)": 381,
#  'Clean Slate (1994)': 382,
#  'Cliffhanger (1993)': 383,
#  'Coneheads (1993)': 384,
#  'Color of Night (1994)': 385,
#  'Cops and Robbersons (1994)': 386,
#  'Cowboy Way, The (1994)': 387,
#  'Dangerous Game (1993)': 388,
#  'Dave (1993)': 389,
#  'Dazed and Confused (1993)': 390,
#  'Demolition Man (1993)': 391,
#  'Endless Summer 2, The (1994)': 392,
#  'Even Cowgirls Get the Blues (1993)': 393,
#  'Fatal Instinct (1993)': 394,
#  'Farewell My Concubine (Ba wang bie ji) (1993)': 395,
#  'Favor, The (1994)': 396,
#  'Fearless (1993)': 397,
#  'Fear of a Black Hat (1994)': 398,
#  'With Honors (1994)': 399,
#  'Flesh and Bone (1993)': 400,
#  "Widows' Peak (1994)": 401,
#  'For Love or Money (1993)': 402,
#  'Firm, The (1993)': 403,
#  'Free Willy (1993)': 404,
#  'Fresh (1994)': 405,
#  'Fugitive, The (1993)': 406,
#  'Geronimo: An American Legend (1993)': 407,
#  'Getaway, The (1994)': 408,
#  'Getting Even with Dad (1994)': 409,
#  'Go Fish (1994)': 410,
#  'Guilty as Sin (1993)': 411,
#  'Hard Target (1993)': 412,
#  'Heaven & Earth (1993)': 413,
#  'Hot Shots! Part Deux (1993)': 414,
#  'Live Nude Girls (1995)': 415,
#  'Englishman Who Went Up a Hill But Came Down a Mountain, The (1995)': 416,
#  'House of the Spirits, The (1993)': 417,
#  'House Party 3 (1994)': 418,
#  'Hudsucker Proxy, The (1994)': 419,
#  "I'll Do Anything (1994)": 420,
#  'In the Army Now (1994)': 421,
#  'In the Line of Fire (1993)': 422,
#  'In the Name of the Father (1993)': 423,
#  'Inkwell, The (1994)': 424,
#  "What's Love Got to Do with It? (1993)": 425,
#  'Judgment Night (1993)': 426,
#  'Jurassic Park (1993)': 427,
#  'Kalifornia (1993)': 428,
#  'Killing Zoe (1994)': 429,
#  'King of the Hill (1993)': 430,
#  'Lassie (1994)': 431,
#  'Last Action Hero (1993)': 432,
#  'Life with Mikey (1993)': 433,
#  'Lightning Jack (1994)': 434,
#  'M. Butterfly (1993)': 435,
#  'Made in America (1993)': 436,
#  'Malice (1993)': 437,
#  'Man Without a Face, The (1993)': 438,
#  'Manhattan Murder Mystery (1993)': 439,
#  'Menace II Society (1993)': 440,
#  'Executive Decision (1996)': 441,
#  'In the Realm of the Senses (Ai no corrida) (1976)': 442,
#  'What Happened Was... (1994)': 443,
#  'Much Ado About Nothing (1993)': 444,
#  'Mr. Jones (1993)': 445,
#  'Mr. Wonderful (1993)': 446,
#  'Mrs. Doubtfire (1993)': 447,
#  'Naked (1993)': 448,
#  'Next Karate Kid, The (1994)': 449,
#  'No Escape (1994)': 450,
#  'North (1994)': 451,
#  'Orlando (1992)': 452,
#  'Perfect World, A (1993)': 453,
#  'Philadelphia (1993)': 454,
#  'Piano, The (1993)': 455,
#  'Poetic Justice (1993)': 456,
#  'Program, The (1993)': 457,
#  'Puppet Masters, The (1994)': 458,
#  'Radioland Murders (1994)': 459,
#  'Ref, The (1994)': 460,
#  'Remains of the Day, The (1993)': 461,
#  'Renaissance Man (1994)': 462,
#  'Rising Sun (1993)': 463,
#  'Road to Wellville, The (1994)': 464,
#  'RoboCop 3 (1993)': 465,
#  'Robin Hood: Men in Tights (1993)': 466,
#  'Romeo Is Bleeding (1993)': 467,
#  'Romper Stomper (1992)': 468,
#  'Ruby in Paradise (1993)': 469,
#  'Rudy (1993)': 470,
#  'Savage Nights (Nuits fauves, Les) (1992)': 471,
#  "Schindler's List (1993)": 472,
#  'Scout, The (1994)': 473,
#  'Searching for Bobby Fischer (1993)': 474,
#  'Secret Garden, The (1993)': 475,
#  'Serial Mom (1994)': 476,
#  'Shadow, The (1994)': 477,
#  'Shadowlands (1993)': 478,
#  'Short Cuts (1993)': 479,
#  'Simple Twist of Fate, A (1994)': 480,
#  'Sirens (1994)': 481,
#  'Six Degrees of Separation (1993)': 482,
#  'Sleepless in Seattle (1993)': 483,
#  'Sliver (1993)': 484,
#  'Blade Runner (1982)': 485,
#  'Son in Law (1993)': 486,
#  'So I Married an Axe Murderer (1993)': 487,
#  'Striking Distance (1993)': 488,
#  'Super Mario Bros. (1993)': 489,
#  'Surviving the Game (1994)': 490,
#  'Terminal Velocity (1994)': 491,
#  'Thirty-Two Short Films About Glenn Gould (1993)': 492,
#  'Threesome (1994)': 493,
#  'Nightmare Before Christmas, The (1993)': 494,
#  'Three Musketeers, The (1993)': 495,
#  'Tombstone (1993)': 496,
#  'Trial by Jury (1994)': 497,
#  'True Romance (1993)': 498,
#  'War Room, The (1993)': 499,
#  'Pagemaster, The (1994)': 500,
#  'Paris, France (1993)': 501,
#  'Killer (Bulletproof Heart) (1994)': 502,
#  'Welcome to the Dollhouse (1995)': 503,
#  'Germinal (1993)': 504,
#  'Chasers (1994)': 505,
#  'Cronos (1993)': 506,
#  'Kika (1993)': 507,
#  'Bhaji on the Beach (1993)': 508,
#  'Little Big League (1994)': 509,
#  'Wedding Gift, The (1994)': 510,
#  'Ciao, Professore! (Io speriamo che me la cavo) (1992)': 511,
#  'Spanking the Monkey (1994)': 512,
#  'Little Rascals, The (1994)': 513,
#  'Andre (1994)': 514,
#  'Princess Caraboo (1994)': 515,
#  'Celluloid Closet, The (1995)': 516,
#  'Métisse (Café au Lait) (1993)': 517,
#  'Brady Bunch Movie, The (1995)': 518,
#  'Home Alone (1990)': 519,
#  'Ghost (1990)': 520,
#  'Aladdin (1992)': 521,
#  'Terminator 2: Judgment Day (1991)': 522,
#  'Dances with Wolves (1990)': 523,
#  'Batman (1989)': 524,
#  'Silence of the Lambs, The (1991)': 525,
#  'Snow White and the Seven Dwarfs (1937)': 526,
#  'Beauty and the Beast (1991)': 527,
#  'Pinocchio (1940)': 528,
#  'Pretty Woman (1990)': 529,
#  'Wild Bunch, The (1969)': 530,
#  'Love and a .45 (1994)': 531,
#  'Bye Bye, Love (1995)': 532,
#  'One Fine Day (1996)': 533,
#  'Candyman: Farewell to the Flesh (1995)': 534,
#  'Fargo (1996)': 535,
#  'Homeward Bound II: Lost in San Francisco (1996)': 536,
#  'Heavy Metal (1981)': 537,
#  'Hellraiser: Bloodline (1996)': 538,
#  'Pallbearer, The (1996)': 539,
#  'Jane Eyre (1996)': 540,
#  'Loaded (1994)': 541,
#  'Bread and Chocolate (Pane e cioccolata) (1973)': 542,
#  'Aristocats, The (1970)': 543,
#  'Flower of My Secret, The (La flor de mi secreto) (1995)': 544,
#  'Ed (1996)': 545,
#  'Scream of Stone (Cerro Torre: Schrei aus Stein) (1991)': 546,
#  'My Favorite Season (1993)': 547,
#  'Thin Line Between Love and Hate, A (1996)': 548,
#  'Last Supper, The (1995)': 549,
#  'Primal Fear (1996)': 550,
#  'Carried Away (1996)': 551,
#  'All Dogs Go to Heaven 2 (1996)': 552,
#  'Land and Freedom (Tierra y libertad) (1995)': 553,
#  'Denise Calls Up (1995)': 554,
#  'Family Thing, A (1996)': 555,
#  'Sgt. Bilko (1996)': 556,
#  'Jack and Sarah (1995)': 557,
#  'Girl 6 (1996)': 558,
#  'Diabolique (1996)': 559,
#  'Courage Under Fire (1996)': 560,
#  'Mission: Impossible (1996)': 561,
#  'Moll Flanders (1996)': 562,
#  'Superweib, Das (1996)': 563,
#  'Dragonheart (1996)': 564,
#  'Eddie (1996)': 565,
#  'Purple Noon (Plein soleil) (1960)': 566,
#  'James and the Giant Peach (1996)': 567,
#  'Fear (1996)': 568,
#  'Kids in the Hall: Brain Candy (1996)': 569,
#  'Faithful (1996)': 570,
#  'Underground (1995)': 571,
#  'Bloodsport 2 (a.k.a. Bloodsport II: The Next Kumite) (1996)': 572,
#  'Song of the Little Road (Pather Panchali) (1955)': 573,
#  'World of Apu, The (Apur Sansar) (1959)': 574,
#  'Mystery Science Theater 3000: The Movie (1996)': 575,
#  'Space Jam (1996)': 576,
#  'Barbarella (1968)': 577,
#  'Some Folks Call It a Sling Blade (1993)': 578,
#  'Run of the Country, The (1995)': 579,
#  'Alphaville (Alphaville, une étrange aventure de Lemmy Caution) (1965)': 580,
#  'Coup de torchon (Clean Slate) (1981)': 581,
#  "It's My Party (1996)": 582,
#  'Country Life (1994)': 583,
#  'Operation Dumbo Drop (1995)': 584,
#  'Promise, The (Versprechen, Das) (1995)': 585,
#  'Mrs. Winterbourne (1996)': 586,
#  'Solo (1996)': 587,
#  'Substitute, The (1996)': 588,
#  'True Crime (1996)': 589,
#  'Butterfly Kiss (1995)': 590,
#  'Feeling Minnesota (1996)': 591,
#  'Delta of Venus (1995)': 592,
#  'Angus (1995)': 593,
#  'Faces (1968)': 594,
#  'Boys (1996)': 595,
#  'Quest, The (1996)': 596,
#  'Cosi (1996)': 597,
#  'Mulholland Falls (1996)': 598,
#  'Truth About Cats & Dogs, The (1996)': 599,
#  'Oliver & Company (1988)': 600,
#  'Celtic Pride (1996)': 601,
#  'Flipper (1996)': 602,
#  'Dead Man (1995)': 603,
#  'Horseman on the Roof, The (Hussard sur le toit, Le) (1995)': 604,
#  'Visitors, The (Visiteurs, Les) (1993)': 605,
#  'Multiplicity (1996)': 606,
#  'Wallace & Gromit: The Best of Aardman Animation (1996)': 607,
#  'Halfmoon (Paul Bowles - Halbmond) (1995)': 608,
#  'Haunted World of Edward D. Wood Jr., The (1996)': 609,
#  'Craft, The (1996)': 610,
#  'Great White Hype, The (1996)': 611,
#  'Last Dance (1996)': 612,
#  'Cold Comfort Farm (1995)': 613,
#  "Heaven's Prisoners (1996)": 614,
#  'Rock, The (1996)': 615,
#  'Cemetery Man (Dellamorte Dellamore) (1994)': 616,
#  'Twister (1996)': 617,
#  'Barb Wire (1996)': 618,
#  'Ghost in the Shell (Kôkaku kidôtai) (1995)': 619,
#  'Thinner (1996)': 620,
#  'Spy Hard (1996)': 621,
#  'Wallace & Gromit: A Close Shave (1995)': 622,
#  'Force of Evil (1948)': 623,
#  'Stupids, The (1996)': 624,
#  'Arrival, The (1996)': 625,
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)': 626,
#  'Month by the Lake, A (1995)': 627,
#  'Gold Diggers: The Secret of Bear Mountain (1995)': 628,
#  'Kim (1950)': 629,
#  'Carmen Miranda: Bananas Is My Business (1994)': 630,
#  'Ashes of Time (Dung che sai duk) (1994)': 631,
#  'Maya Lin: A Strong Clear Vision (1994)': 632,
#  'Stalingrad (1993)': 633,
#  'Phantom, The (1996)': 634,
#  'Striptease (1996)': 635,
#  'Heavy (1995)': 636,
#  'Jack (1996)': 637,
#  'I Shot Andy Warhol (1996)': 638,
#  'Grass Harp, The (1995)': 639,
#  'Marlene Dietrich: Shadow and Light (1996)': 640,
#  'Spirits of the Dead (1968)': 641,
#  'Trainspotting (1996)': 642,
#  "'Til There Was You (1997)": 643,
#  'Independence Day (a.k.a. ID4) (1996)': 644,
#  'Stealing Beauty (1996)': 645,
#  'Fan, The (1996)': 646,
#  'Hunchback of Notre Dame, The (1996)': 647,
#  'Cable Guy, The (1996)': 648,
#  'Kingpin (1996)': 649,
#  'Eraser (1996)': 650,
#  'Gate of Heavenly Peace, The (1995)': 651,
#  'Nutty Professor, The (1996)': 652,
#  "My Life and Times With Antonin Artaud (En compagnie d'Antonin Artaud) (1993)": 653,
#  'Daylight (1996)': 654,
#  'Frighteners, The (1996)': 655,
#  'Lone Star (1996)': 656,
#  'Harriet the Spy (1996)': 657,
#  'Phenomenon (1996)': 658,
#  'Walking and Talking (1996)': 659,
#  "She's the One (1996)": 660,
#  'Time to Kill, A (1996)': 661,
#  'American Buffalo (1996)': 662,
#  'Alaska (1996)': 663,
#  'Fled (1996)': 664,
#  'Kazaam (1996)': 665,
#  'Larger Than Life (1996)': 666,
#  'Two Deaths (1995)': 667,
#  'Very Brady Sequel, A (1996)': 668,
#  'Death in the Garden (Mort en ce jardin, La) (1956)': 669,
#  'Kaspar Hauser (1993)': 670,
#  'Adventures of Pinocchio, The (1996)': 671,
#  "Joe's Apartment (1996)": 672,
#  'First Wives Club, The (1996)': 673,
#  'Stonewall (1995)': 674,
#  'Ransom (1996)': 675,
#  'High School High (1996)': 676,
#  'Phat Beach (1996)': 677,
#  'Foxfire (1996)': 678,
#  'Chain Reaction (1996)': 679,
#  'Matilda (1996)': 680,
#  'Emma (1996)': 681,
#  'Crow: City of Angels, The (1996)': 682,
#  'House Arrest (1996)': 683,
#  'Eyes Without a Face (Yeux sans visage, Les) (1959)': 684,
#  'Tales from the Crypt Presents: Bordello of Blood (1996)': 685,
#  'Story of Xinghua, The (Xinghua san yue tian) (1994)': 686,
#  'Day the Sun Turned Cold, The (Tianguo niezi) (1994)': 687,
#  'Flirt (1995)': 688,
#  'Spitfire Grill, The (1996)': 689,
#  'Escape from L.A. (1996)': 690,
#  'Cyclo (Xich lo) (1995)': 691,
#  'Basquiat (1996)': 692,
#  'Tin Cup (1996)': 693,
#  'Ballad of Narayama, The (Narayama Bushiko) (1958)': 694,
#  'Godfather, The (1972)': 695,
#  'Supercop (Police Story 3: Supercop) (Jing cha gu shi III: Chao ji jing cha) (1992)': 696,
#  'Wife, The (1995)': 697,
#  'Small Faces (1996)': 698,
#  'Bound (1996)': 699,
#  'Carpool (1996)': 700,
#  'Kansas City (1996)': 701,
#  "Gone Fishin' (1997)": 702,
#  "Vive L'Amour (Ai qing wan sui) (1994)": 703,
#  'Nothing to Lose (1994)': 704,
#  'Supercop 2 (Project S) (Chao ji ji hua) (1993)': 705,
#  'Relic, The (1997)': 706,
#  'Island of Dr. Moreau, The (1996)': 707,
#  'First Kid (1996)': 708,
#  'Trigger Effect, The (1996)': 709,
#  'Bogus (1996)': 710,
#  'Bulletproof (1996)': 711,
#  'Land Before Time III: The Time of the Great Giving (1995)': 712,
#  '1-900 (06) (1994)': 713,
#  'Halloween: The Curse of Michael Myers (Halloween 6: The Curse of Michael Myers) (1995)': 714,
#  'Twelfth Night (1996)': 715,
#  'Mother Night (1996)': 716,
#  'Wild Reeds (Les roseaux sauvages) (1994)': 717,
#  'For Whom the Bell Tolls (1943)': 718,
#  'Philadelphia Story, The (1940)': 719,
#  "Singin' in the Rain (1952)": 720,
#  'American in Paris, An (1951)': 721,
#  'Funny Face (1957)': 722,
#  "Breakfast at Tiffany's (1961)": 723,
#  'Vertigo (1958)': 724,
#  'Rear Window (1954)': 725,
#  'It Happened One Night (1934)': 726,
#  'Gaslight (1944)': 727,
#  'Gay Divorcee, The (1934)': 728,
#  'North by Northwest (1959)': 729,
#  'Apartment, The (1960)': 730,
#  'Some Like It Hot (1959)': 731,
#  'Charade (1963)': 732,
#  'Casablanca (1942)': 733,
#  'Maltese Falcon, The (1941)': 734,
#  'My Fair Lady (1964)': 735,
#  'Sabrina (1954)': 736,
#  'Roman Holiday (1953)': 737,
#  'Little Princess, The (1939)': 738,
#  'Meet Me in St. Louis (1944)': 739,
#  'Wizard of Oz, The (1939)': 740,
#  'Gone with the Wind (1939)': 741,
#  'My Favorite Year (1982)': 742,
#  'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)': 743,
#  'Citizen Kane (1941)': 744,
#  '2001: A Space Odyssey (1968)': 745,
#  'All About Eve (1950)': 746,
#  'Women, The (1939)': 747,
#  'Rebecca (1940)': 748,
#  'Foreign Correspondent (1940)': 749,
#  'Notorious (1946)': 750,
#  'Spellbound (1945)': 751,
#  'Affair to Remember, An (1957)': 752,
#  'To Catch a Thief (1955)': 753,
#  'Father of the Bride (1950)': 754,
#  'Band Wagon, The (1953)': 755,
#  'Ninotchka (1939)': 756,
#  'Love in the Afternoon (1957)': 757,
#  'Gigi (1958)': 758,
#  'Reluctant Debutante, The (1958)': 759,
#  'Adventures of Robin Hood, The (1938)': 760,
#  'Mark of Zorro, The (1940)': 761,
#  'Laura (1944)': 762,
#  'Ghost and Mrs. Muir, The (1947)': 763,
#  'Lost Horizon (1937)': 764,
#  'Top Hat (1935)': 765,
#  'To Be or Not to Be (1942)': 766,
#  'My Man Godfrey (1936)': 767,
#  'Giant (1956)': 768,
#  'East of Eden (1955)': 769,
#  'Thin Man, The (1934)': 770,
#  'His Girl Friday (1940)': 771,
#  'Around the World in 80 Days (1956)': 772,
#  "It's a Wonderful Life (1946)": 773,
#  'Mr. Smith Goes to Washington (1939)': 774,
#  'Bringing Up Baby (1938)': 775,
#  'Penny Serenade (1941)': 776,
#  'Scarlet Letter, The (1926)': 777,
#  'Angel on My Shoulder (1946)': 778,
#  'Little Lord Fauntleroy (1936)': 779,
#  'They Made Me a Criminal (1939)': 780,
#  'Inspector General, The (1949)': 781,
#  'Angel and the Badman (1947)': 782,
#  '39 Steps, The (1935)': 783,
#  'A Walk in the Sun (1945)': 784,
#  'Night of the Living Dead (1968)': 785,
#  'African Queen, The (1951)': 786,
#  'Beat the Devil (1953)': 787,
#  'Cat on a Hot Tin Roof (1958)': 788,
#  'Last Time I Saw Paris, The (1954)': 789,
#  'Meet John Doe (1941)': 790,
#  'Farewell to Arms, A (1932)': 791,
#  'Yes, Madam (a.k.a. Police Assassins) (a.k.a. In the Line of Duty 2) (Huang gu shi jie) (1985)': 792,
#  'Dangerous Ground (1997)': 793,
#  'Picnic (1955)': 794,
#  'Pompatus of Love, The (1996)': 795,
#  'Fly Away Home (1996)': 796,
#  'Bliss (1997)': 797,
#  'Grace of My Heart (1996)': 798,
#  'Maximum Risk (1996)': 799,
#  'Michael Collins (1996)': 800,
#  "Rich Man's Wife, The (1996)": 801,
#  'Big Night (1996)': 802,
#  'Last Man Standing (1996)': 803,
#  'Caught (1996)': 804,
#  'Set It Off (1996)': 805,
#  '2 Days in the Valley (1996)': 806,
#  'Extreme Measures (1996)': 807,
#  'Glimmer Man, The (1996)': 808,
#  'D3: The Mighty Ducks (1996)': 809,
#  'Chamber, The (1996)': 810,
#  'Apple Dumpling Gang, The (1975)': 811,
#  'Davy Crockett, King of the Wild Frontier (1955)': 812,
#  'Escape to Witch Mountain (1975)': 813,
#  'Love Bug, The (1969)': 814,
#  'Herbie Rides Again (1974)': 815,
#  'Old Yeller (1957)': 816,
#  'Parent Trap, The (1961)': 817,
#  'Pollyanna (1960)': 818,
#  'Homeward Bound: The Incredible Journey (1993)': 819,
#  'Shaggy Dog, The (1959)': 820,
#  'Swiss Family Robinson (1960)': 821,
#  'That Darn Cat! (1965)': 822,
#  '20,000 Leagues Under the Sea (1954)': 823,
#  'Cool Runnings (1993)': 824,
#  'Angels in the Outfield (1994)': 825,
#  'Cinderella (1950)': 826,
#  'Winnie the Pooh and the Blustery Day (1968)': 827,
#  'Three Caballeros, The (1945)': 828,
#  'Sword in the Stone, The (1963)': 829,
#  'So Dear to My Heart (1949)': 830,
#  'Robin Hood: Prince of Thieves (1991)': 831,
#  'Mary Poppins (1964)': 832,
#  'Dumbo (1941)': 833,
#  "Pete's Dragon (1977)": 834,
#  'Bedknobs and Broomsticks (1971)': 835,
#  'Alice in Wonderland (1951)': 836,
#  'Fox and the Hound, The (1981)': 837,
#  'Freeway (1996)': 838,
#  'Sound of Music, The (1965)': 839,
#  'Die Hard (1988)': 840,
#  'Lawnmower Man, The (1992)': 841,
#  'Secret Agent, The (1996)': 842,
#  'Secrets & Lies (1996)': 843,
#  'That Thing You Do! (1996)': 844,
#  'To Gillian on Her 37th Birthday (1996)': 845,
#  'Surviving Picasso (1996)': 846,
#  'Beautiful Thing (1996)': 847,
#  'Long Kiss Goodnight, The (1996)': 848,
#  'Ghost and the Darkness, The (1996)': 849,
#  'Looking for Richard (1996)': 850,
#  'Trees Lounge (1996)': 851,
#  'Normal Life (1996)': 852,
#  'Get on the Bus (1996)': 853,
#  'Shadow Conspiracy (1997)': 854,
#  'Jude (1996)': 855,
#  'Everyone Says I Love You (1996)': 856,
#  "William Shakespeare's Romeo + Juliet (1996)": 857,
#  'Swingers (1996)': 858,
#  'Sleepers (1996)': 859,
#  'Johns (1996)': 860,
#  'Aladdin and the King of Thieves (1996)': 861,
#  'Shall We Dance (1937)': 862,
#  'Damsel in Distress, A (1937)': 863,
#  'Crossfire (1947)': 864,
#  'Murder, My Sweet (1944)': 865,
#  'Willy Wonka & the Chocolate Factory (1971)': 866,
#  'Innocents, The (1961)': 867,
#  'Sleeper (1973)': 868,
#  'Bananas (1971)': 869,
#  'Fish Called Wanda, A (1988)': 870,
#  "Monty Python's Life of Brian (1979)": 871,
#  'Victor/Victoria (1982)': 872,
#  'Candidate, The (1972)': 873,
#  'Great Race, The (1965)': 874,
#  'Bonnie and Clyde (1967)': 875,
#  'Old Man and the Sea, The (1958)': 876,
#  'Dial M for Murder (1954)': 877,
#  'Madame Butterfly (1995)': 878,
#  'Dirty Dancing (1987)': 879,
#  'Reservoir Dogs (1992)': 880,
#  'Platoon (1986)': 881,
#  "Weekend at Bernie's (1989)": 882,
#  'Basic Instinct (1992)': 883,
#  'Doors, The (1991)': 884,
#  'Crying Game, The (1992)': 885,
#  'Glengarry Glen Ross (1992)': 886,
#  "Sophie's Choice (1982)": 887,
#  'E.T. the Extra-Terrestrial (1982)': 888,
#  'Christmas Carol, A (1938)': 889,
#  'Days of Thunder (1990)': 890,
#  'Top Gun (1986)': 891,
#  'Rebel Without a Cause (1955)': 892,
#  'Streetcar Named Desire, A (1951)': 893,
#  'Children of the Corn IV: The Gathering (1996)': 894,
#  "Microcosmos (Microcosmos: Le peuple de l'herbe) (1996)": 895,
#  'Palookaville (1996)': 896,
#  'Associate, The (1996)': 897,
#  'Funeral, The (1996)': 898,
#  'People vs. Larry Flynt, The (1996)': 899,
#  'Perfect Candidate, A (1996)': 900,
#  'On Golden Pond (1981)': 901,
#  'Return of the Pink Panther, The (1975)': 902,
#  'Drop Dead Fred (1991)': 903,
#  'Abyss, The (1989)': 904,
#  'Fog, The (1980)': 905,
#  'Escape from New York (1981)': 906,
#  'Howling, The (1980)': 907,
#  'Jean de Florette (1986)': 908,
#  'Manon of the Spring (Manon des sources) (1986)': 909,
#  'Talking About Sex (1994)': 910,
#  'Private Benjamin (1980)': 911,
#  'Monty Python and the Holy Grail (1975)': 912,
#  'Hustler White (1996)': 913,
#  'Snowriders (1996)': 914,
#  'When We Were Kings (1996)': 915,
#  'Wallace & Gromit: The Wrong Trousers (1993)': 916,
#  'Return of Martin Guerre, The (Retour de Martin Guerre, Le) (1982)': 917,
#  'Lesson Faust (1994)': 918,
#  'He Walked by Night (1948)': 919,
#  'Raw Deal (1948)': 920,
#  'T-Men (1947)': 921,
#  'Tin Drum, The (Blechtrommel, Die) (1979)': 922,
#  'Ruling Class, The (1972)': 923,
#  'Mina Tannenbaum (1994)': 924,
#  "2 ou 3 choses que je sais d'elle (2 or 3 Things I Know About Her) (1967)": 925,
#  'Bloody Child, The (1996)': 926,
#  'Dear God (1996)': 927,
#  'Bad Moon (1996)': 928,
#  'American Dream (1990)': 929,
#  'Bob Roberts (1992)': 930,
#  'Cinema Paradiso (Nuovo cinema Paradiso) (1989)': 931,
#  'Cook the Thief His Wife & Her Lover, The (1989)': 932,
#  'Dead Tired (Grosse Fatigue) (1994)': 933,
#  'Delicatessen (1991)': 934,
#  'Double Life of Veronique, The (Double Vie de Véronique, La) (1991)': 935,
#  'Enchanted April (1992)': 936,
#  'Paths of Glory (1957)': 937,
#  'Grifters, The (1990)': 938,
#  'Hear My Song (1991)': 939,
#  'Shooter, The (1997)': 940,
#  'English Patient, The (1996)': 941,
#  'Mediterraneo (1991)': 942,
#  'My Left Foot (1989)': 943,
#  'Sex, Lies, and Videotape (1989)': 944,
#  'Passion Fish (1992)': 945,
#  'Strictly Ballroom (1992)': 946,
#  'Thin Blue Line, The (1988)': 947,
#  'Tie Me Up! Tie Me Down! (¡Átame!) (1990)': 948,
#  'Madonna: Truth or Dare (1991)': 949,
#  'Paris Is Burning (1990)': 950,
#  "One Flew Over the Cuckoo's Nest (1975)": 951,
#  "Cheech and Chong's Up in Smoke (1978)": 952,
#  'Star Wars: Episode V - The Empire Strikes Back (1980)': 953,
#  'Princess Bride, The (1987)': 954,
#  'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)': 955,
#  'Brazil (1985)': 956,
#  'Aliens (1986)': 957,
#  'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)': 958,
#  'Withnail & I (1987)': 959,
#  '12 Angry Men (1957)': 960,
#  'Lawrence of Arabia (1962)': 961,
#  'Clockwork Orange, A (1971)': 962,
#  'To Kill a Mockingbird (1962)': 963,
#  'Apocalypse Now (1979)': 964,
#  "Once Upon a Time in the West (C'era una volta il West) (1968)": 965,
#  'Star Wars: Episode VI - Return of the Jedi (1983)': 966,
#  'Wings of Desire (Himmel über Berlin, Der) (1987)': 967,
#  'Third Man, The (1949)': 968,
#  'Goodfellas (1990)': 969,
#  'Alien (1979)': 970,
#  'Army of Darkness (1993)': 971,
#  'Big Blue, The (Grand bleu, Le) (1988)': 972,
#  'Ran (1985)': 973,
#  'Killer, The (Die xue shuang xiong) (1989)': 974,
#  'Psycho (1960)': 975,
#  'Blues Brothers, The (1980)': 976,
#  'Godfather: Part II, The (1974)': 977,
#  'Full Metal Jacket (1987)': 978,
#  'Grand Day Out with Wallace and Gromit, A (1989)': 979,
#  'Henry V (1989)': 980,
#  'Amadeus (1984)': 981,
#  'Quiet Man, The (1952)': 982,
#  'Once Upon a Time in America (1984)': 983,
#  'Raging Bull (1980)': 984,
#  'Annie Hall (1977)': 985,
#  'Right Stuff, The (1983)': 986,
#  'Stalker (1979)': 987,
#  'Boot, Das (Boat, The) (1981)': 988,
#  'Sting, The (1973)': 989,
#  'Harold and Maude (1971)': 990,
#  'Trust (1990)': 991,
#  'Seventh Seal, The (Sjunde inseglet, Det) (1957)': 992,
#  'Local Hero (1983)': 993,
#  'Terminator, The (1984)': 994,
#  'Dead Alive (Braindead) (1992)': 995,
#  'Glory (1989)': 996,
#  'Rosencrantz and Guildenstern Are Dead (1990)': 997,
#  'Manhattan (1979)': 998,
#  "Miller's Crossing (1990)": 999,
#  ...}

# %% [markdown]
# 3 fitting the model KNN 클러스터링 적용하기

# %%
# %env JOBLIB_TEMP_FOLDER=/tmp
# define model
model_knn = NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=20, n_jobs=-1)
# fit
model_knn.fit(movie_user_mat_sparse)
# Out:
# env: JOBLIB_TEMP_FOLDER=/tmp
# NearestNeighbors(algorithm='brute', leaf_size=30, metric='cosine',
#                  metric_params=None, n_jobs=-1, n_neighbors=20, p=2,
#                  radius=1.0)

# %% [markdown]
# 4 movie reccommendations KNN 기준으로 영화 추천해주기

# %%
def fuzzy_matching(mapper, fav_movie, verbose=True):
    """
    return the closest match via fuzzy ratio. If no match found, return None
    
    Parameters
    ----------    
    mapper: dict, map movie title name to index of the movie in data

    fav_movie: str, name of user input movie
    
    verbose: bool, print log if True

    Return
    ------
    index of the closest match
    """
    match_tuple = []
    # get match
    for title, idx in mapper.items():
        ratio = fuzz.ratio(title.lower(), fav_movie.lower())
        if ratio >= 60:
            match_tuple.append((title, idx, ratio))
    # sort
    match_tuple = sorted(match_tuple, key=lambda x: x[2])[::-1]
    if not match_tuple:
        print('Oops! No match is found')
        return
    if verbose:
        print('Found possible matches in our database: {0}\n'.format([x[0] for x in match_tuple]))
    return match_tuple[0][1]



def make_recommendation(model_knn, data, mapper, fav_movie, n_recommendations):
    """
    return top n similar movie recommendations based on user's input movie


    Parameters
    ----------
    model_knn: sklearn model, knn model

    data: movie-user matrix

    mapper: dict, map movie title name to index of the movie in data

    fav_movie: str, name of user input movie

    n_recommendations: int, top n recommendations

    Return
    ------
    list of top n similar movie recommendations
    """
    # fit
    model_knn.fit(data)
    # get input movie index
    print('You have input movie:', fav_movie)
    idx = fuzzy_matching(mapper, fav_movie, verbose=True)
    # inference
    print('Recommendation system start to make inference')
    print('......\n')
    distances, indices = model_knn.kneighbors(data[idx], n_neighbors=n_recommendations+1)
    # get list of raw idx of recommendations
    raw_recommends = \
        sorted(list(zip(indices.squeeze().tolist(), distances.squeeze().tolist())), key=lambda x: x[1])[:0:-1]
    # get reverse mapper
    reverse_mapper = {v: k for k, v in mapper.items()}
    # print recommendations
    print('Recommendations for {}:'.format(fav_movie))
    for i, (idx, dist) in enumerate(raw_recommends):
        print('{0}: {1}, with distance of {2}'.format(i+1, reverse_mapper[idx], dist))

# %%
my_favorite = str((input("Enter the movie title  you want to recommend : ")))
make_recommendation(
    #사용 알고리즘 knn
    model_knn=model_knn,
    # 사용할 데이터 - 정렬해놓은 sparse matrix
    data=movie_user_mat_sparse,
    # 유사한 영화 찾고자하는 좋아하는 movie
    fav_movie=my_favorite,
    # index로 영화를 찾아서
    mapper=movie_to_idx,
    # n 개의 개수만큼 정렬하기
    n_recommendations=10)
# Out:
# Enter the movie title  you want to recommend : toy story
# You have input movie: toy story
# Found possible matches in our database: ['Toy Story (1995)', 'Toy Story 3 (2010)', 'Toy Story 2 (1999)']
#
# Recommendation system start to make inference
# ......
#
# Recommendations for toy story:
# 1: Pulp Fiction (1994), with distance of 0.473138425840108
# 2: Star Wars: Episode VI - Return of the Jedi (1983), with distance of 0.4706659556910192
# 3: Shrek (2001), with distance of 0.46731490125936237
# 4: Jurassic Park (1993), with distance of 0.4648029221631048
# 5: Back to the Future (1985), with distance of 0.4632997104257994
# 6: Groundhog Day (1993), with distance of 0.45197697860072394
# 7: Independence Day (a.k.a. ID4) (1996), with distance of 0.4370543997396795
# 8: Forrest Gump (1994), with distance of 0.4354661385473587
# 9: Star Wars: Episode IV - A New Hope (1977), with distance of 0.4238121540234343
# 10: Toy Story 2 (1999), with distance of 0.4052901879681512

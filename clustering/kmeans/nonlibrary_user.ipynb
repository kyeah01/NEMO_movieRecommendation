# %% [markdown]
# # 유저 기반 영화추천 (라이브러리 사용 X)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.sparse import csr_matrix
import helper

# %%
# Import the Movies dataset
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Import the ratings dataset
ratings = pd.read_csv('ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
# Merge the two tables then pivot so we have Users X Movies dataframe
ratings_title = pd.merge(ratings, movies[['movieId', 'title']], on='movieId' )
user_movie_ratings = pd.pivot_table(ratings_title, index='userId', columns= 'title', values='rating')

# print('dataset dimensions: ', user_movie_ratings.shape, '\n\nSubset example:')
# user_movie_ratings.iloc[:6, :10]

# %%
n_movies = 30
n_users = 18
most_rated_movies_users_selection = helper.sort_by_rating_density(user_movie_ratings, n_movies, n_users)

most_rated_movies_users_selection

# %%
user_movie_ratings =  pd.pivot_table(ratings_title, index='userId', columns= 'title', values='rating')
most_rated_movies_1k = helper.get_most_rated_movies(user_movie_ratings, 1000)
most_rated_movies_1k
# Out:
# title  Forrest Gump (1994)  Pulp Fiction (1994)  \
# 0                      NaN                  NaN
# 1                      3.0                  4.0
# 2                      5.0                  4.5
# 3                      5.0                  5.0
# 4                      4.0                  NaN
# ..                     ...                  ...
# 666                    4.0                  5.0
# 667                    NaN                  5.0
# 668                    NaN                  NaN
# 669                    NaN                  NaN
# 670                    5.0                  4.0
#
# title  Shawshank Redemption, The (1994)  Silence of the Lambs, The (1991)  \
# 0                                   NaN                               NaN
# 1                                   NaN                               3.0
# 2                                   5.0                               3.0
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
# ..                                  ...                               ...
# 666                                 NaN                               NaN
# 667                                 4.0                               5.0
# 668                                 NaN                               NaN
# 669                                 5.0                               5.0
# 670                                 5.0                               NaN
#
# title  Star Wars: Episode IV - A New Hope (1977)  Jurassic Park (1993)  \
# 0                                            NaN                   NaN
# 1                                            NaN                   4.0
# 2                                            NaN                   NaN
# 3                                            5.0                   5.0
# 4                                            NaN                   NaN
# ..                                           ...                   ...
# 666                                          NaN                   4.0
# 667                                          NaN                   NaN
# 668                                          5.0                   3.0
# 669                                          NaN                   NaN
# 670                                          5.0                   NaN
#
# title  Matrix, The (1999)  Toy Story (1995)  Schindler's List (1993)  \
# 0                     NaN               NaN                      NaN
# 1                     NaN               NaN                      4.0
# 2                     NaN               NaN                      3.0
# 3                     NaN               NaN                      NaN
# 4                     NaN               NaN                      NaN
# ..                    ...               ...                      ...
# 666                   NaN               NaN                      NaN
# 667                   NaN               NaN                      NaN
# 668                   NaN               NaN                      NaN
# 669                   4.0               4.0                      5.0
# 670                   4.5               5.0                      NaN
#
# title  Terminator 2: Judgment Day (1991)  ...  Insomnia (2002)  \
# 0                                    NaN  ...              NaN
# 1                                    5.0  ...              NaN
# 2                                    NaN  ...              NaN
# 3                                    5.0  ...              NaN
# 4                                    NaN  ...              NaN
# ..                                   ...  ...              ...
# 666                                  NaN  ...              NaN
# 667                                  NaN  ...              NaN
# 668                                  NaN  ...              NaN
# 669                                  NaN  ...              NaN
# 670                                  5.0  ...              NaN
#
# title  What Lies Beneath (2000)  Roman Holiday (1953)  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
# ..                          ...                   ...
# 666                         NaN                   NaN
# 667                         NaN                   NaN
# 668                         NaN                   NaN
# 669                         NaN                   NaN
# 670                         NaN                   NaN
#
# title  Motorcycle Diaries, The (Diarios de motocicleta) (2004)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ..                                                   ...
# 666                                                  NaN
# 667                                                  NaN
# 668                                                  NaN
# 669                                                  NaN
# 670                                                  NaN
#
# title  Sophie's Choice (1982)  Dawn of the Dead (2004)  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# ..                        ...                      ...
# 666                       NaN                      NaN
# 667                       NaN                      NaN
# 668                       NaN                      NaN
# 669                       NaN                      NaN
# 670                       NaN                      NaN
#
# title  Ocean's Thirteen (2007)  Seabiscuit (2003)  Easy Rider (1969)  \
# 0                          NaN                NaN                NaN
# 1                          NaN                NaN                NaN
# 2                          NaN                NaN                NaN
# 3                          NaN                NaN                NaN
# 4                          NaN                NaN                NaN
# ..                         ...                ...                ...
# 666                        NaN                NaN                NaN
# 667                        NaN                NaN                NaN
# 668                        NaN                NaN                NaN
# 669                        NaN                NaN                NaN
# 670                        NaN                3.5                NaN
#
# title  Lucky Number Slevin (2006)
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ..                            ...
# 666                           NaN
# 667                           NaN
# 668                           NaN
# 669                           NaN
# 670                           NaN
#
# [671 rows x 1000 columns]

# %%
class kmeans:
    def __init__(self, k , input):
        self.k = k
        self.df = input
        self.C =None

    # K개의 중심값을 임의로 선택한다

    def centroids(self):
        import random
        C = {
        i+1:[data for data in self.df.values[i]]
        for i, j in zip(range(self.k), random.sample(range(len(self.df)),self.k))}
        return C

    # 각 중심에서 데이터까지의 거리를 계산 using up.linalg.norm
    # 각 데이터에 가장 가까운 중심점(군집)을 할당
        
    def classify(self,C):
        import copy
        cluster_df = copy.deepcopy(self.df)
        col_n = cluster_df.shape[1]
        for i in C.keys():
            cluster_df["Distance_from_{}".format(i)]\
            =np.linalg.norm(np.array(cluster_df)[:,:col_n]-C[i], axis=1)

        dist_cols=["Distance_from_{}".format(i)  for i in C.keys()]
        cluster_df["Closet_Cluster"] = cluster_df.loc[:,dist_cols].idxmin(axis=1).map(lambda x:int(x.lstrip("Distance_from")))
        return cluster_df

    #각 중심점에 선택된 데이터 포인터들의 평균위치로 중심점을 재이동
    def update(self, C):
        c_df = self.classify(C)
        self.C ={
        i:[c for c in np.mean(self.df[c_df["Closet_Cluster"]==i], axis=0)]
        for i in c_df["Closet_Cluster"].unique()}
        return self.C

    # 위 과정을 '갱신된 중심점이 거의 변화가 없어 할당된 군집이 바뀌지 않을만큼 반복

    def train_cluster(self):
        assignments = None
        C = self.centroids()
        while True:
            # 중심점에 해당하는 군집 찾기
            cluster_df = self.classify(C)
            new_assignments = list(self.classify(C)["Closet_Cluster"])
            # 새로운 중심점 찾기
            new_C = self.update(C)
            # 할당된 군집이 바뀌지 않을만큼 중심점이 수렴했다면 종료
            if assignments == new_assignments:
                break
            # 아니라면 다시 중심점과 군집 찾기
            assignments = new_assignments
            C = new_C

        return new_C, list(new_assignments), cluster_df

# %%
predictions = kmeans(10, most_rated_movies_1k.fillna(0))

# %%
cluster = predictions.train_cluster()

# %%
predictions_1 = np.array(cluster[2]['Closet_Cluster'])

# %%
clustered_user = {}
for idx in range(len(predictions_1)):
    c_user = []
    for i in range(len(predictions_1)):
        if idx == i:
            continue
        if predictions_1[idx] == predictions_1[i]:
            c_user.append(i)
    clustered_user[idx] = c_user

# print("clustered_user : ", clustered_user.keys())
print("clustered_movie : ", clustered_user)
# Out:
# clustered_movie :  {0: [2, 5, 8, 9, 10, 11, 12, 13, 15, 17, 19, 23, 24, 26, 27, 28, 30, 32, 34, 36, 39, 42, 43, 44, 45, 48, 50, 51, 52, 53, 54, 57, 58, 59, 61, 64, 65, 69, 70, 73, 75, 78, 79, 80, 86, 89, 95, 97, 99, 102, 103, 105, 106, 108, 111, 112, 114, 115, 116, 121, 122, 126, 128, 130, 131, 132, 134, 135, 137, 138, 139, 140, 141, 142, 146, 152, 153, 155, 157, 159, 161, 162, 163, 165, 166, 169, 170, 171, 172, 173, 178, 179, 180, 182, 185, 188, 189, 192, 195, 197, 201, 202, 203, 205, 206, 207, 208, 209, 210, 214, 217, 220, 221, 222, 225, 226, 228, 230, 232, 236, 237, 245, 248, 251, 254, 255, 256, 257, 258, 259, 260, 262, 263, 266, 268, 271, 273, 275, 276, 277, 279, 280, 283, 285, 288, 289, 292, 295, 296, 297, 298, 299, 300, 303, 304, 306, 307, 309, 313, 314, 317, 318, 319, 320, 321, 322, 324, 325, 326, 328, 329, 330, 331, 332, 333, 334, 335, 336, 338, 339, 340, 342, 346, 347, 348, 350, 351, 355, 356, 358, 359, 360, 363, 364, 365, 367, 371, 373, 375, 376, 377, 380, 382, 385, 390, 391, 392, 394, 396, 397, 398, 402, 403, 405, 409, 410, 412, 413, 418, 419, 421, 423, 424, 426, 428, 434, 435, 436, 437, 442, 443, 444, 445, 447, 450, 452, 453, 454, 458, 461, 463, 464, 466, 468, 469, 472, 473, 475, 476, 481, 483, 484, 487, 488, 489, 490, 491, 492, 493, 496, 497, 498, 502, 503, 505, 506, 510, 511, 514, 520, 523, 525, 527, 529, 530, 531, 537, 538, 539, 540, 541, 542, 544, 545, 548, 550, 551, 553, 556, 564, 565, 566, 568, 570, 571, 572, 575, 577, 578, 580, 581, 582, 585, 590, 598, 599, 600, 603, 605, 608, 609, 610, 611, 612, 613, 615, 616, 617, 619, 620, 621, 624, 625, 627, 629, 630, 631, 633, 634, 635, 636, 637, 639, 641, 642, 643, 644, 649, 650, 651, 652, 655, 656, 657, 659, 660, 662, 667, 668, 669], 1: [31, 35, 38, 46, 49, 63, 66, 81, 84, 85, 91, 107, 109, 113, 120, 125, 143, 144, 150, 160, 167, 181, 183, 187, 190, 191, 193, 223, 224, 240, 253, 265, 278, 287, 301, 316, 337, 343, 353, 368, 374, 384, 388, 395, 399, 408, 414, 415, 420, 439, 446, 448, 486, 494, 495, 507, 512, 515, 516, 533, 534, 535, 547, 554, 555, 567, 587, 588, 589, 592, 601, 618, 628, 632, 638, 640, 648, 658, 661, 665, 666], 2: [0, 5, 8, 9, 10, 11, 12, 13, 15, 17, 19, 23, 24, 26, 27, 28, 30, 32, 34, 36, 39, 42, 43, 44, 45, 48, 50, 51, 52, 53, 54, 57, 58, 59, 61, 64, 65, 69, 70, 73, 75, 78, 79, 80, 86, 89, 95, 97, 99, 102, 103, 105, 106, 108, 111, 112, 114, 115, 116, 121, 122, 126, 128, 130, 131, 132, 134, 135, 137, 138, 139, 140, 141, 142, 146, 152, 153, 155, 157, 159, 161, 162, 163, 165, 166, 169, 170, 171, 172, 173, 178, 179, 180, 182, 185, 188, 189, 192, 195, 197, 201, 202, 203, 205, 206, 207, 208, 209, 210, 214, 217, 220, 221, 222, 225, 226, 228, 230, 232, 236, 237, 245, 248, 251, 254, 255, 256, 257, 258, 259, 260, 262, 263, 266, 268, 271, 273, 275, 276, 277, 279, 280, 283, 285, 288, 289, 292, 295, 296, 297, 298, 299, 300, 303, 304, 306, 307, 309, 313, 314, 317, 318, 319, 320, 321, 322, 324, 325, 326, 328, 329, 330, 331, 332, 333, 334, 335, 336, 338, 339, 340, 342, 346, 347, 348, 350, 351, 355, 356, 358, 359, 360, 363, 364, 365, 367, 371, 373, 375, 376, 377, 380, 382, 385, 390, 391, 392, 394, 396, 397, 398, 402, 403, 405, 409, 410, 412, 413, 418, 419, 421, 423, 424, 426, 428, 434, 435, 436, 437, 442, 443, 444, 445, 447, 450, 452, 453, 454, 458, 461, 463, 464, 466, 468, 469, 472, 473, 475, 476, 481, 483, 484, 487, 488, 489, 490, 491, 492, 493, 496, 497, 498, 502, 503, 505, 506, 510, 511, 514, 520, 523, 525, 527, 529, 530, 531, 537, 538, 539, 540, 541, 542, 544, 545, 548, 550, 551, 553, 556, 564, 565, 566, 568, 570, 571, 572, 575, 577, 578, 580, 581, 582, 585, 590, 598, 599, 600, 603, 605, 608, 609, 610, 611, 612, 613, 615, 616, 617, 619, 620, 621, 624, 625, 627, 629, 630, 631, 633, 634, 635, 636, 637, 639, 641, 642, 643, 644, 649, 650, 651, 652, 655, 656, 657, 659, 660, 662, 667, 668, 669], 3: [18, 20, 56, 76, 129, 184, 194, 213, 284, 293, 310, 362, 441, 465, 504, 513, 536, 574, 576], 4: [312], 5: [0, 2, 8, 9, 10, 11, 12, 13, 15, 17, 19, 23, 24, 26, 27, 28, 30, 32, ...

# %% [markdown]
# # 실습

# %% [markdown]
# ## (1) user id 받아오기

# %%
user_id = 99

# %% [markdown]
# ## (2) 비슷한 user id 가져오기

# %%
clustered_user[user_id]
# Out:
# [0,
#  2,
#  5,
#  8,
#  9,
#  10,
#  11,
#  12,
#  13,
#  15,
#  17,
#  19,
#  23,
#  24,
#  26,
#  27,
#  28,
#  30,
#  32,
#  34,
#  36,
#  39,
#  42,
#  43,
#  44,
#  45,
#  48,
#  50,
#  51,
#  52,
#  53,
#  54,
#  57,
#  58,
#  59,
#  61,
#  64,
#  65,
#  69,
#  70,
#  73,
#  75,
#  78,
#  79,
#  80,
#  86,
#  89,
#  95,
#  97,
#  102,
#  103,
#  105,
#  106,
#  108,
#  111,
#  112,
#  114,
#  115,
#  116,
#  121,
#  122,
#  126,
#  128,
#  130,
#  131,
#  132,
#  134,
#  135,
#  137,
#  138,
#  139,
#  140,
#  141,
#  142,
#  146,
#  152,
#  153,
#  155,
#  157,
#  159,
#  161,
#  162,
#  163,
#  165,
#  166,
#  169,
#  170,
#  171,
#  172,
#  173,
#  178,
#  179,
#  180,
#  182,
#  185,
#  188,
#  189,
#  192,
#  195,
#  197,
#  201,
#  202,
#  203,
#  205,
#  206,
#  207,
#  208,
#  209,
#  210,
#  214,
#  217,
#  220,
#  221,
#  222,
#  225,
#  226,
#  228,
#  230,
#  232,
#  236,
#  237,
#  245,
#  248,
#  251,
#  254,
#  255,
#  256,
#  257,
#  258,
#  259,
#  260,
#  262,
#  263,
#  266,
#  268,
#  271,
#  273,
#  275,
#  276,
#  277,
#  279,
#  280,
#  283,
#  285,
#  288,
#  289,
#  292,
#  295,
#  296,
#  297,
#  298,
#  299,
#  300,
#  303,
#  304,
#  306,
#  307,
#  309,
#  313,
#  314,
#  317,
#  318,
#  319,
#  320,
#  321,
#  322,
#  324,
#  325,
#  326,
#  328,
#  329,
#  330,
#  331,
#  332,
#  333,
#  334,
#  335,
#  336,
#  338,
#  339,
#  340,
#  342,
#  346,
#  347,
#  348,
#  350,
#  351,
#  355,
#  356,
#  358,
#  359,
#  360,
#  363,
#  364,
#  365,
#  367,
#  371,
#  373,
#  375,
#  376,
#  377,
#  380,
#  382,
#  385,
#  390,
#  391,
#  392,
#  394,
#  396,
#  397,
#  398,
#  402,
#  403,
#  405,
#  409,
#  410,
#  412,
#  413,
#  418,
#  419,
#  421,
#  423,
#  424,
#  426,
#  428,
#  434,
#  435,
#  436,
#  437,
#  442,
#  443,
#  444,
#  445,
#  447,
#  450,
#  452,
#  453,
#  454,
#  458,
#  461,
#  463,
#  464,
#  466,
#  468,
#  469,
#  472,
#  473,
#  475,
#  476,
#  481,
#  483,
#  484,
#  487,
#  488,
#  489,
#  490,
#  491,
#  492,
#  493,
#  496,
#  497,
#  498,
#  502,
#  503,
#  505,
#  506,
#  510,
#  511,
#  514,
#  520,
#  523,
#  525,
#  527,
#  529,
#  530,
#  531,
#  537,
#  538,
#  539,
#  540,
#  541,
#  542,
#  544,
#  545,
#  548,
#  550,
#  551,
#  553,
#  556,
#  564,
#  565,
#  566,
#  568,
#  570,
#  571,
#  572,
#  575,
#  577,
#  578,
#  580,
#  581,
#  582,
#  585,
#  590,
#  598,
#  599,
#  600,
#  603,
#  605,
#  608,
#  609,
#  610,
#  611,
#  612,
#  613,
#  615,
#  616,
#  617,
#  619,
#  620,
#  621,
#  624,
#  625,
#  627,
#  629,
#  630,
#  631,
#  633,
#  634,
#  635,
#  636,
#  637,
#  639,
#  641,
#  642,
#  643,
#  644,
#  649,
#  650,
#  651,
#  652,
#  655,
#  656,
#  657,
#  659,
#  660,
#  662,
#  667,
#  668,
#  669]
